# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 731

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city.
city_data = []

# Print a message to indicate that the data retrieval starts.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description})
        
# If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | naryan-mar
# Processing Record 2 of Set 1 | saint-augustin
# Processing Record 3 of Set 1 | okandja
# City not found. Skipping...
# Processing Record 4 of Set 1 | cape town
# Processing Record 5 of Set 1 | tema
# Processing Record 6 of Set 1 | kismayo
# Processing Record 7 of Set 1 | khatanga
# Processing Record 8 of Set 1 | longyearbyen
# Processing Record 9 of Set 1 | ayagoz
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | punta arenas
# Processing Record 12 of Set 1 | semenivka
# Processing Record 13 of Set 1 | arraial do cabo
# Processing Record 14 of Set 1 | xining
# Processing Record 15 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 16 of Set 1 | namibe
# Processing Record 17 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 18 of Set 1 | mataura
# Processing Record 19 of Set 1 | avarua
# Processing Record 20 of Set 1 | dingle
# Processing Record 21 of Set 1 | aykhal
# Processing Record 22 of Set 1 | westport
# Processing Record 23 of Set 1 | khani
# Processing Record 24 of Set 1 | tuktoyaktuk
# Processing Record 25 of Set 1 | ulaanbaatar
# Processing Record 26 of Set 1 | kavieng
# Processing Record 27 of Set 1 | vaini
# Processing Record 28 of Set 1 | georgetown
# Processing Record 29 of Set 1 | nikolskoye
# Processing Record 30 of Set 1 | provideniya
# Processing Record 31 of Set 1 | doka
# Processing Record 32 of Set 1 | alice springs
# Processing Record 33 of Set 1 | helong
# Processing Record 34 of Set 1 | guigue
# Processing Record 35 of Set 1 | kapaa
# Processing Record 36 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 37 of Set 1 | ushuaia
# Processing Record 38 of Set 1 | busselton
# Processing Record 39 of Set 1 | saint-denis
# Processing Record 40 of Set 1 | jamestown
# Processing Record 41 of Set 1 | uwayl
# City not found. Skipping...
# Processing Record 42 of Set 1 | pevek
# Processing Record 43 of Set 1 | albany
# Processing Record 44 of Set 1 | cherskiy
# Processing Record 45 of Set 1 | yanan
# City not found. Skipping...
# Processing Record 46 of Set 1 | airai
# Processing Record 47 of Set 1 | skjervoy
# Processing Record 48 of Set 1 | kahului
# Processing Record 49 of Set 1 | male
# Processing Record 50 of Set 1 | butaritari
# Processing Record 1 of Set 2 | ponta do sol
# Processing Record 2 of Set 2 | brignoles
# Processing Record 3 of Set 2 | bredasdorp
# Processing Record 4 of Set 2 | mar del plata
# Processing Record 5 of Set 2 | rundu
# Processing Record 6 of Set 2 | malakal
# Processing Record 7 of Set 2 | pisco
# Processing Record 8 of Set 2 | sur
# Processing Record 9 of Set 2 | leningradskiy
# Processing Record 10 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 11 of Set 2 | camara de lobos
# Processing Record 12 of Set 2 | raudeberg
# Processing Record 13 of Set 2 | tomatlan
# Processing Record 14 of Set 2 | bengkulu
# Processing Record 15 of Set 2 | lazaro cardenas
# Processing Record 16 of Set 2 | novikovo
# Processing Record 17 of Set 2 | saint-philippe
# Processing Record 18 of Set 2 | tessalit
# Processing Record 19 of Set 2 | faanui
# Processing Record 20 of Set 2 | xiangdong
# City not found. Skipping...
# Processing Record 21 of Set 2 | pavino
# Processing Record 22 of Set 2 | vermilion
# Processing Record 23 of Set 2 | esperance
# Processing Record 24 of Set 2 | san ramon
# Processing Record 25 of Set 2 | hermanus
# Processing Record 26 of Set 2 | uhlove
# Processing Record 27 of Set 2 | tura
# Processing Record 28 of Set 2 | ilulissat
# Processing Record 29 of Set 2 | talaya
# Processing Record 30 of Set 2 | vryheid
# Processing Record 31 of Set 2 | port moresby
# Processing Record 32 of Set 2 | bambous virieux
# Processing Record 33 of Set 2 | hithadhoo
# Processing Record 34 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 35 of Set 2 | nelson bay
# Processing Record 36 of Set 2 | honiara
# Processing Record 37 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 38 of Set 2 | srednekolymsk
# Processing Record 39 of Set 2 | avera
# Processing Record 40 of Set 2 | vila franca do campo
# Processing Record 41 of Set 2 | dikson
# Processing Record 42 of Set 2 | kruisfontein
# Processing Record 43 of Set 2 | snasa
# Processing Record 44 of Set 2 | kristinehamn
# Processing Record 45 of Set 2 | hovd
# Processing Record 46 of Set 2 | batagay-alyta
# Processing Record 47 of Set 2 | skagastrond
# City not found. Skipping...
# Processing Record 48 of Set 2 | upernavik
# Processing Record 49 of Set 2 | pangnirtung
# Processing Record 50 of Set 2 | bluefield
# Processing Record 1 of Set 3 | tuatapere
# Processing Record 2 of Set 3 | rawson
# Processing Record 3 of Set 3 | yellowknife
# Processing Record 4 of Set 3 | mount isa
# Processing Record 5 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 6 of Set 3 | kaitangata
# Processing Record 7 of Set 3 | port elizabeth
# Processing Record 8 of Set 3 | mogadishu
# Processing Record 9 of Set 3 | puerto ayora
# Processing Record 10 of Set 3 | zuwarah
# Processing Record 11 of Set 3 | saint-pierre
# Processing Record 12 of Set 3 | siavonga
# Processing Record 13 of Set 3 | vrede
# Processing Record 14 of Set 3 | paamiut
# Processing Record 15 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 16 of Set 3 | coralville
# Processing Record 17 of Set 3 | aklavik
# Processing Record 18 of Set 3 | komsomolskiy
# Processing Record 19 of Set 3 | east london
# Processing Record 20 of Set 3 | ust-maya
# Processing Record 21 of Set 3 | pandan
# Processing Record 22 of Set 3 | qaanaaq
# Processing Record 23 of Set 3 | vila velha
# Processing Record 24 of Set 3 | naze
# Processing Record 25 of Set 3 | plaridel
# Processing Record 26 of Set 3 | cabo san lucas
# Processing Record 27 of Set 3 | ramshir
# Processing Record 28 of Set 3 | izhevskoye
# Processing Record 29 of Set 3 | lebu
# Processing Record 30 of Set 3 | auki
# Processing Record 31 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 32 of Set 3 | taoudenni
# Processing Record 33 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 34 of Set 3 | chokurdakh
# Processing Record 35 of Set 3 | jesup
# Processing Record 36 of Set 3 | maldonado
# Processing Record 37 of Set 3 | sitka
# Processing Record 38 of Set 3 | kavaratti
# Processing Record 39 of Set 3 | ancud
# Processing Record 40 of Set 3 | wyndham
# Processing Record 41 of Set 3 | victoria
# Processing Record 42 of Set 3 | ambanja
# Processing Record 43 of Set 3 | fortuna
# Processing Record 44 of Set 3 | bolonchen
# City not found. Skipping...
# Processing Record 45 of Set 3 | shenjiamen
# Processing Record 46 of Set 3 | iracoubo
# Processing Record 47 of Set 3 | castro
# Processing Record 48 of Set 3 | warrnambool
# Processing Record 49 of Set 3 | saskylakh
# Processing Record 50 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 1 of Set 4 | sambir
# Processing Record 2 of Set 4 | anjar
# Processing Record 3 of Set 4 | klaksvik
# Processing Record 4 of Set 4 | hasaki
# Processing Record 5 of Set 4 | porto murtinho
# Processing Record 6 of Set 4 | te anau
# Processing Record 7 of Set 4 | sabha
# Processing Record 8 of Set 4 | freeport
# Processing Record 9 of Set 4 | oranjestad
# Processing Record 10 of Set 4 | dunedin
# Processing Record 11 of Set 4 | kangalassy
# Processing Record 12 of Set 4 | port macquarie
# Processing Record 13 of Set 4 | gushikawa
# Processing Record 14 of Set 4 | hamilton
# Processing Record 15 of Set 4 | buchanan
# Processing Record 16 of Set 4 | katsuura
# Processing Record 17 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 18 of Set 4 | jalu
# Processing Record 19 of Set 4 | la ronge
# Processing Record 20 of Set 4 | rapid valley
# Processing Record 21 of Set 4 | domoni
# Processing Record 22 of Set 4 | cabedelo
# Processing Record 23 of Set 4 | amga
# Processing Record 24 of Set 4 | vestmannaeyjar
# Processing Record 25 of Set 4 | chuy
# Processing Record 26 of Set 4 | marystown
# Processing Record 27 of Set 4 | emerald
# Processing Record 28 of Set 4 | kristiansund
# Processing Record 29 of Set 4 | tarko-sale
# Processing Record 30 of Set 4 | mehamn
# Processing Record 31 of Set 4 | san cristobal
# Processing Record 32 of Set 4 | atuona
# Processing Record 33 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 34 of Set 4 | port alfred
# Processing Record 35 of Set 4 | anadyr
# Processing Record 36 of Set 4 | bom jardim
# Processing Record 37 of Set 4 | zhigansk
# Processing Record 38 of Set 4 | qaqortoq
# Processing Record 39 of Set 4 | sao joao da barra
# Processing Record 40 of Set 4 | margate
# Processing Record 41 of Set 4 | tasiilaq
# Processing Record 42 of Set 4 | roebourne
# Processing Record 43 of Set 4 | hualmay
# Processing Record 44 of Set 4 | taksimo
# Processing Record 45 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 46 of Set 4 | berlevag
# Processing Record 47 of Set 4 | nanortalik
# Processing Record 48 of Set 4 | naliya
# Processing Record 49 of Set 4 | limon
# Processing Record 50 of Set 4 | carnarvon
# Processing Record 1 of Set 5 | geraldton
# Processing Record 2 of Set 5 | cauquenes
# Processing Record 3 of Set 5 | nabire
# Processing Record 4 of Set 5 | talnakh
# Processing Record 5 of Set 5 | sanford
# Processing Record 6 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 7 of Set 5 | adre
# Processing Record 8 of Set 5 | matara
# Processing Record 9 of Set 5 | canchungo
# Processing Record 10 of Set 5 | borovoy
# Processing Record 11 of Set 5 | constitucion
# Processing Record 12 of Set 5 | ravar
# Processing Record 13 of Set 5 | meulaboh
# Processing Record 14 of Set 5 | salalah
# Processing Record 15 of Set 5 | barrow
# Processing Record 16 of Set 5 | matadi
# Processing Record 17 of Set 5 | ballina
# Processing Record 18 of Set 5 | saint-georges
# Processing Record 19 of Set 5 | kayerkan
# Processing Record 20 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 21 of Set 5 | harlingen
# Processing Record 22 of Set 5 | new norfolk
# Processing Record 23 of Set 5 | lodja
# Processing Record 24 of Set 5 | sao jose da coroa grande
# Processing Record 25 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 26 of Set 5 | hofn
# Processing Record 27 of Set 5 | thompson
# Processing Record 28 of Set 5 | hobart
# Processing Record 29 of Set 5 | mayo
# Processing Record 30 of Set 5 | mountain home
# Processing Record 31 of Set 5 | makakilo city
# Processing Record 32 of Set 5 | bethel
# Processing Record 33 of Set 5 | bathsheba
# Processing Record 34 of Set 5 | zhuhai
# Processing Record 35 of Set 5 | pleasanton
# Processing Record 36 of Set 5 | sovetskiy
# Processing Record 37 of Set 5 | chumikan
# Processing Record 38 of Set 5 | saint cyrus
# City not found. Skipping...
# Processing Record 39 of Set 5 | kungurtug
# Processing Record 40 of Set 5 | palmer
# Processing Record 41 of Set 5 | saint george
# Processing Record 42 of Set 5 | ribeira grande
# Processing Record 43 of Set 5 | kampot
# Processing Record 44 of Set 5 | am timan
# Processing Record 45 of Set 5 | dongzhen
# Processing Record 46 of Set 5 | dwarka
# Processing Record 47 of Set 5 | san policarpo
# Processing Record 48 of Set 5 | chalons-en-champagne
# Processing Record 49 of Set 5 | wajima
# Processing Record 50 of Set 5 | pochutla
# Processing Record 1 of Set 6 | chipinge
# Processing Record 2 of Set 6 | opelousas
# Processing Record 3 of Set 6 | bartica
# Processing Record 4 of Set 6 | pemba
# Processing Record 5 of Set 6 | san patricio
# Processing Record 6 of Set 6 | mahebourg
# Processing Record 7 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 8 of Set 6 | cidreira
# Processing Record 9 of Set 6 | khandyga
# Processing Record 10 of Set 6 | tual
# Processing Record 11 of Set 6 | hokitika
# Processing Record 12 of Set 6 | port hardy
# Processing Record 13 of Set 6 | camacha
# Processing Record 14 of Set 6 | codrington
# Processing Record 15 of Set 6 | akyab
# Processing Record 16 of Set 6 | kalamata
# Processing Record 17 of Set 6 | bluff
# Processing Record 18 of Set 6 | ipora
# Processing Record 19 of Set 6 | dumabato
# Processing Record 20 of Set 6 | humberto de campos
# Processing Record 21 of Set 6 | paracuru
# Processing Record 22 of Set 6 | narsaq
# Processing Record 23 of Set 6 | fairbanks
# Processing Record 24 of Set 6 | sola
# Processing Record 25 of Set 6 | chekhov
# Processing Record 26 of Set 6 | luderitz
# Processing Record 27 of Set 6 | sabang
# Processing Record 28 of Set 6 | praia da vitoria
# Processing Record 29 of Set 6 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 30 of Set 6 | tyumentsevo
# Processing Record 31 of Set 6 | andradas
# Processing Record 32 of Set 6 | tiksi
# Processing Record 33 of Set 6 | turbat
# Processing Record 34 of Set 6 | shirokiy
# Processing Record 35 of Set 6 | kurchum
# Processing Record 36 of Set 6 | carmo do paranaiba
# Processing Record 37 of Set 6 | nizwa
# Processing Record 38 of Set 6 | deputatskiy
# Processing Record 39 of Set 6 | bajo baudo
# City not found. Skipping...
# Processing Record 40 of Set 6 | tateyama
# Processing Record 41 of Set 6 | saint anthony
# Processing Record 42 of Set 6 | zavodskoy
# Processing Record 43 of Set 6 | yomitan
# City not found. Skipping...
# Processing Record 44 of Set 6 | ixtapa
# Processing Record 45 of Set 6 | peniche
# Processing Record 46 of Set 6 | kloulklubed
# Processing Record 47 of Set 6 | dubuque
# Processing Record 48 of Set 6 | lincoln
# Processing Record 49 of Set 6 | severo-kurilsk
# Processing Record 50 of Set 6 | ketchikan
# Processing Record 1 of Set 7 | campoverde
# Processing Record 2 of Set 7 | quelimane
# Processing Record 3 of Set 7 | belyy yar
# Processing Record 4 of Set 7 | xuanhua
# Processing Record 5 of Set 7 | wanning
# Processing Record 6 of Set 7 | araouane
# Processing Record 7 of Set 7 | kodiak
# Processing Record 8 of Set 7 | kisangani
# Processing Record 9 of Set 7 | fort saint james
# Processing Record 10 of Set 7 | sao filipe
# Processing Record 11 of Set 7 | port hedland
# Processing Record 12 of Set 7 | kenitra
# Processing Record 13 of Set 7 | santa rosa
# Processing Record 14 of Set 7 | marrakesh
# Processing Record 15 of Set 7 | college
# Processing Record 16 of Set 7 | harper
# Processing Record 17 of Set 7 | yaan
# Processing Record 18 of Set 7 | fagernes
# Processing Record 19 of Set 7 | beocin
# Processing Record 20 of Set 7 | barra do garcas
# Processing Record 21 of Set 7 | mackay
# Processing Record 22 of Set 7 | pamanukan
# Processing Record 23 of Set 7 | sorong
# Processing Record 24 of Set 7 | guaruja
# Processing Record 25 of Set 7 | tunduru
# City not found. Skipping...
# Processing Record 26 of Set 7 | navolato
# Processing Record 27 of Set 7 | biak
# Processing Record 28 of Set 7 | barra do corda
# Processing Record 29 of Set 7 | karkaralinsk
# City not found. Skipping...
# Processing Record 30 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 31 of Set 7 | norman wells
# Processing Record 32 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 33 of Set 7 | kupang
# Processing Record 34 of Set 7 | shache
# Processing Record 35 of Set 7 | praia
# Processing Record 36 of Set 7 | buraydah
# Processing Record 37 of Set 7 | bud
# Processing Record 38 of Set 7 | benguela
# Processing Record 39 of Set 7 | hilo
# Processing Record 40 of Set 7 | leme
# Processing Record 41 of Set 7 | zhanaozen
# Processing Record 42 of Set 7 | ahipara
# Processing Record 43 of Set 7 | dien bien
# City not found. Skipping...
# Processing Record 44 of Set 7 | havre-saint-pierre
# Processing Record 45 of Set 7 | tsienyane
# City not found. Skipping...
# Processing Record 46 of Set 7 | dolores
# Processing Record 47 of Set 7 | reading
# Processing Record 48 of Set 7 | hermon
# Processing Record 49 of Set 7 | gizo
# Processing Record 50 of Set 7 | novyy urengoy
# Processing Record 1 of Set 8 | ruatoria
# City not found. Skipping...
# Processing Record 2 of Set 8 | guarapari
# Processing Record 3 of Set 8 | swinoujscie
# Processing Record 4 of Set 8 | silver city
# Processing Record 5 of Set 8 | russell
# Processing Record 6 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 7 of Set 8 | gryazovets
# Processing Record 8 of Set 8 | porgera
# Processing Record 9 of Set 8 | ola
# Processing Record 10 of Set 8 | balimo
# City not found. Skipping...
# Processing Record 11 of Set 8 | coquimbo
# Processing Record 12 of Set 8 | north bend
# Processing Record 13 of Set 8 | axim
# Processing Record 14 of Set 8 | polican
# Processing Record 15 of Set 8 | bardiyah
# Processing Record 16 of Set 8 | kyabe
# Processing Record 17 of Set 8 | nizhniye vyazovyye
# Processing Record 18 of Set 8 | guerrero negro
# Processing Record 19 of Set 8 | mount gambier
# Processing Record 20 of Set 8 | langsa
# Processing Record 21 of Set 8 | boralday
# Processing Record 22 of Set 8 | buala
# Processing Record 23 of Set 8 | gurkovo
# Processing Record 24 of Set 8 | alta floresta
# Processing Record 25 of Set 8 | souillac
# Processing Record 26 of Set 8 | yulara
# Processing Record 27 of Set 8 | walvis bay
# Processing Record 28 of Set 8 | turukhansk
# Processing Record 29 of Set 8 | gornoye loo
# Processing Record 30 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 31 of Set 8 | svetlogorsk
# Processing Record 32 of Set 8 | zarya
# Processing Record 33 of Set 8 | pampas
# Processing Record 34 of Set 8 | jiddah
# City not found. Skipping...
# Processing Record 35 of Set 8 | broome
# Processing Record 36 of Set 8 | staraya vichuga
# Processing Record 37 of Set 8 | konstantinovskaya
# Processing Record 38 of Set 8 | uruzgan
# Processing Record 39 of Set 8 | baykalsk
# Processing Record 40 of Set 8 | kangaatsiaq
# Processing Record 41 of Set 8 | bubaque
# Processing Record 42 of Set 8 | poum
# Processing Record 43 of Set 8 | inyonga
# Processing Record 44 of Set 8 | hanyang
# Processing Record 45 of Set 8 | valdivia
# Processing Record 46 of Set 8 | kalmunai
# Processing Record 47 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 48 of Set 8 | muisne
# Processing Record 49 of Set 8 | mantua
# Processing Record 50 of Set 8 | vaitape
# Processing Record 1 of Set 9 | caravelas
# Processing Record 2 of Set 9 | singaparna
# Processing Record 3 of Set 9 | saint-joseph
# Processing Record 4 of Set 9 | tapaua
# City not found. Skipping...
# Processing Record 5 of Set 9 | varzelandia
# Processing Record 6 of Set 9 | aflao
# Processing Record 7 of Set 9 | port lincoln
# Processing Record 8 of Set 9 | vardo
# Processing Record 9 of Set 9 | bonavista
# Processing Record 10 of Set 9 | lompoc
# Processing Record 11 of Set 9 | vicuna
# Processing Record 12 of Set 9 | tecoanapa
# Processing Record 13 of Set 9 | makat
# Processing Record 14 of Set 9 | nemuro
# Processing Record 15 of Set 9 | santa fe
# Processing Record 16 of Set 9 | idrinskoye
# Processing Record 17 of Set 9 | san juan bautista
# Processing Record 18 of Set 9 | itaituba
# Processing Record 19 of Set 9 | saldanha
# Processing Record 20 of Set 9 | polyarnyye zori
# Processing Record 21 of Set 9 | ostrovnoy
# Processing Record 22 of Set 9 | touros
# Processing Record 23 of Set 9 | warren
# Processing Record 24 of Set 9 | muroto
# Processing Record 25 of Set 9 | grafton
# Processing Record 26 of Set 9 | samoylovka
# Processing Record 27 of Set 9 | moerai
# Processing Record 28 of Set 9 | katherine
# Processing Record 29 of Set 9 | erzin
# Processing Record 30 of Set 9 | rocha
# Processing Record 31 of Set 9 | mocuba
# Processing Record 32 of Set 9 | hambantota
# Processing Record 33 of Set 9 | ushtobe
# Processing Record 34 of Set 9 | port-gentil
# Processing Record 35 of Set 9 | leshukonskoye
# Processing Record 36 of Set 9 | plettenberg bay
# Processing Record 37 of Set 9 | catalina
# Processing Record 38 of Set 9 | husavik
# Processing Record 39 of Set 9 | camana
# Processing Record 40 of Set 9 | puerto maldonado
# Processing Record 41 of Set 9 | sorland
# Processing Record 42 of Set 9 | brahmapuri
# City not found. Skipping...
# Processing Record 43 of Set 9 | padang
# Processing Record 44 of Set 9 | mariakani
# Processing Record 45 of Set 9 | fort walton beach
# Processing Record 46 of Set 9 | karasburg
# Processing Record 47 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 48 of Set 9 | okhotsk
# Processing Record 49 of Set 9 | sonoita
# Processing Record 50 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 1 of Set 10 | nishihara
# Processing Record 2 of Set 10 | anloga
# Processing Record 3 of Set 10 | prince rupert
# Processing Record 4 of Set 10 | coahuayana
# Processing Record 5 of Set 10 | san juan
# Processing Record 6 of Set 10 | halifax
# Processing Record 7 of Set 10 | marzuq
# Processing Record 8 of Set 10 | olecko
# Processing Record 9 of Set 10 | champerico
# Processing Record 10 of Set 10 | joshimath
# Processing Record 11 of Set 10 | lorengau
# Processing Record 12 of Set 10 | cairns
# Processing Record 13 of Set 10 | turayf
# Processing Record 14 of Set 10 | polyarnyy
# Processing Record 15 of Set 10 | qui nhon
# Processing Record 16 of Set 10 | bell ville
# Processing Record 17 of Set 10 | cloquet
# Processing Record 18 of Set 10 | sisimiut
# Processing Record 19 of Set 10 | kivsharivka
# Processing Record 20 of Set 10 | izhma
# Processing Record 21 of Set 10 | adrar
# Processing Record 22 of Set 10 | tashla
# Processing Record 23 of Set 10 | slave lake
# Processing Record 24 of Set 10 | portland
# Processing Record 25 of Set 10 | linjiang
# Processing Record 26 of Set 10 | chernogorsk
# Processing Record 27 of Set 10 | jinchang
# Processing Record 28 of Set 10 | richards bay
# Processing Record 29 of Set 10 | pokrovsk
# Processing Record 30 of Set 10 | gerash
# Processing Record 31 of Set 10 | labutta
# City not found. Skipping...
# Processing Record 32 of Set 10 | aracuai
# Processing Record 33 of Set 10 | semey
# Processing Record 34 of Set 10 | beya
# Processing Record 35 of Set 10 | inuvik
# Processing Record 36 of Set 10 | sao borja
# Processing Record 37 of Set 10 | boueni
# Processing Record 38 of Set 10 | pontianak
# Processing Record 39 of Set 10 | dong hoi
# Processing Record 40 of Set 10 | lusambo
# Processing Record 41 of Set 10 | ust-barguzin
# Processing Record 42 of Set 10 | umm kaddadah
# Processing Record 43 of Set 10 | korla
# Processing Record 44 of Set 10 | scottsburgh
# City not found. Skipping...
# Processing Record 45 of Set 10 | suntar
# Processing Record 46 of Set 10 | asau
# Processing Record 47 of Set 10 | sterling
# Processing Record 48 of Set 10 | trinidad
# Processing Record 49 of Set 10 | yar-sale
# Processing Record 50 of Set 10 | severnoye
# Processing Record 1 of Set 11 | bagan
# Processing Record 2 of Set 11 | lahaina
# Processing Record 3 of Set 11 | lerwick
# Processing Record 4 of Set 11 | tawkar
# City not found. Skipping...
# Processing Record 5 of Set 11 | conway
# Processing Record 6 of Set 11 | madison
# Processing Record 7 of Set 11 | aswan
# Processing Record 8 of Set 11 | oussouye
# Processing Record 9 of Set 11 | beringovskiy
# Processing Record 10 of Set 11 | xuddur
# Processing Record 11 of Set 11 | torbay
# Processing Record 12 of Set 11 | cartagena
# Processing Record 13 of Set 11 | bandarbeyla
# Processing Record 14 of Set 11 | cockburn town
# Processing Record 15 of Set 11 | topolobampo
# Processing Record 16 of Set 11 | yumen
# Processing Record 17 of Set 11 | shakawe
# Processing Record 18 of Set 11 | laguna
# Processing Record 19 of Set 11 | baykit
# Processing Record 20 of Set 11 | pokosnoye
# Processing Record 21 of Set 11 | harrison
# Processing Record 22 of Set 11 | lavrentiya
# Processing Record 23 of Set 11 | ruteng
# Processing Record 24 of Set 11 | mrirt
# City not found. Skipping...
# Processing Record 25 of Set 11 | umm lajj
# Processing Record 26 of Set 11 | ciudad del maiz
# Processing Record 27 of Set 11 | araguacu
# Processing Record 28 of Set 11 | igarka
# Processing Record 29 of Set 11 | marsh harbour
# Processing Record 30 of Set 11 | xichang
# Processing Record 31 of Set 11 | alunitdag
# City not found. Skipping...
# Processing Record 32 of Set 11 | riyadh
# Processing Record 33 of Set 11 | grand forks
# Processing Record 34 of Set 11 | simao
# Processing Record 35 of Set 11 | waipawa
# Processing Record 36 of Set 11 | ilo
# Processing Record 37 of Set 11 | alofi
# Processing Record 38 of Set 11 | princeville
# Processing Record 39 of Set 11 | moron
# Processing Record 40 of Set 11 | inhambane
# Processing Record 41 of Set 11 | tornio
# Processing Record 42 of Set 11 | itoman
# Processing Record 43 of Set 11 | nagod
# Processing Record 44 of Set 11 | buariki
# City not found. Skipping...
# Processing Record 45 of Set 11 | isangel
# Processing Record 46 of Set 11 | baruun-urt
# Processing Record 47 of Set 11 | kaiserslautern
# Processing Record 48 of Set 11 | pontes e lacerda
# Processing Record 49 of Set 11 | manyana
# Processing Record 50 of Set 11 | tautira
# Processing Record 1 of Set 12 | aksarka
# Processing Record 2 of Set 12 | manuk mangkaw
# Processing Record 3 of Set 12 | vao
# Processing Record 4 of Set 12 | morondava
# Processing Record 5 of Set 12 | shelburne
# Processing Record 6 of Set 12 | harindanga
# Processing Record 7 of Set 12 | camargo
# Processing Record 8 of Set 12 | hirara
# Processing Record 9 of Set 12 | san lawrenz
# Processing Record 10 of Set 12 | ustynivka
# Processing Record 11 of Set 12 | manokwari
# Processing Record 12 of Set 12 | bursa
# Processing Record 13 of Set 12 | daru
# Processing Record 14 of Set 12 | gejiu
# Processing Record 15 of Set 12 | clyde river
# Processing Record 16 of Set 12 | jumla
# Processing Record 17 of Set 12 | fort nelson
# Processing Record 18 of Set 12 | hadzici
# Processing Record 19 of Set 12 | hihifo
# City not found. Skipping...
# Processing Record 20 of Set 12 | villa carlos paz
# Processing Record 21 of Set 12 | vallenar
# Processing Record 22 of Set 12 | murray bridge
# Processing Record 23 of Set 12 | rawannawi
# City not found. Skipping...
# Processing Record 24 of Set 12 | ust-nera
# Processing Record 25 of Set 12 | lasa
# Processing Record 26 of Set 12 | victor harbor
# Processing Record 27 of Set 12 | ormond beach
# Processing Record 28 of Set 12 | pappadatai
# Processing Record 29 of Set 12 | soure
# Processing Record 30 of Set 12 | bom jesus
# Processing Record 31 of Set 12 | chirongui
# Processing Record 32 of Set 12 | longlac
# City not found. Skipping...
# Processing Record 33 of Set 12 | wilmington
# Processing Record 34 of Set 12 | lakes entrance
# Processing Record 35 of Set 12 | goderich
# Processing Record 36 of Set 12 | sarangani
# Processing Record 37 of Set 12 | itarema
# Processing Record 38 of Set 12 | sayat
# Processing Record 39 of Set 12 | miri
# Processing Record 40 of Set 12 | alghero
# Processing Record 41 of Set 12 | maningrida
# Processing Record 42 of Set 12 | zlatoustovsk
# City not found. Skipping...
# Processing Record 43 of Set 12 | punta gorda
# Processing Record 44 of Set 12 | aranos
# Processing Record 45 of Set 12 | grindavik
# Processing Record 46 of Set 12 | nome
# Processing Record 47 of Set 12 | qeshm
# Processing Record 48 of Set 12 | tuy hoa
# Processing Record 49 of Set 12 | barrhead
# Processing Record 50 of Set 12 | soyo
# Processing Record 1 of Set 13 | port hawkesbury
# Processing Record 2 of Set 13 | dariba
# Processing Record 3 of Set 13 | sandovo
# Processing Record 4 of Set 13 | tulsipur
# Processing Record 5 of Set 13 | hiriyur
# Processing Record 6 of Set 13 | kiama
# Processing Record 7 of Set 13 | velykoploske
# Processing Record 8 of Set 13 | port said
# Processing Record 9 of Set 13 | melilla
# Processing Record 10 of Set 13 | kannabe
# Processing Record 11 of Set 13 | pinkafeld
# Processing Record 12 of Set 13 | broken hill
# Processing Record 13 of Set 13 | asayita
# City not found. Skipping...
# Processing Record 14 of Set 13 | santa cruz
# Processing Record 15 of Set 13 | berbera
# Processing Record 16 of Set 13 | les cayes
# Processing Record 17 of Set 13 | olafsvik
# Processing Record 18 of Set 13 | inta
# Processing Record 19 of Set 13 | umea
# Processing Record 20 of Set 13 | usinsk
# Processing Record 21 of Set 13 | ginda
# Processing Record 22 of Set 13 | piacabucu
# Processing Record 23 of Set 13 | atbasar
# Processing Record 24 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 25 of Set 13 | vila
# Processing Record 26 of Set 13 | yarmolyntsi
# Processing Record 27 of Set 13 | atambua
# Processing Record 28 of Set 13 | singleton
# Processing Record 29 of Set 13 | zalantun
# Processing Record 30 of Set 13 | yuzhnyy
# Processing Record 31 of Set 13 | iqaluit
# Processing Record 32 of Set 13 | asfi
# Processing Record 33 of Set 13 | parrita
# Processing Record 34 of Set 13 | innisfail
# Processing Record 35 of Set 13 | phangnga
# Processing Record 36 of Set 13 | taquarituba
# Processing Record 37 of Set 13 | penzance
# Processing Record 38 of Set 13 | bansi
# Processing Record 39 of Set 13 | juneau
# Processing Record 40 of Set 13 | teya
# Processing Record 41 of Set 13 | mao
# Processing Record 42 of Set 13 | sale
# Processing Record 43 of Set 13 | mangrol
# Processing Record 44 of Set 13 | moyale
# Processing Record 45 of Set 13 | pacific grove
# Processing Record 46 of Set 13 | ullal
# Processing Record 47 of Set 13 | formoso do araguaia
# City not found. Skipping...
# Processing Record 48 of Set 13 | narrabri
# Processing Record 49 of Set 13 | vitim
# Processing Record 50 of Set 13 | umm durman
# City not found. Skipping...
# Processing Record 1 of Set 14 | tshikapa
# Processing Record 2 of Set 14 | martapura
# Processing Record 3 of Set 14 | minab
# Processing Record 4 of Set 14 | high level
# Processing Record 5 of Set 14 | sidney
# Processing Record 6 of Set 14 | griffith
# Processing Record 7 of Set 14 | bay roberts
# Processing Record 8 of Set 14 | conner
# Processing Record 9 of Set 14 | vilkija
# Processing Record 10 of Set 14 | changping
# Processing Record 11 of Set 14 | cheuskiny
# City not found. Skipping...
# Processing Record 12 of Set 14 | challans
# Processing Record 13 of Set 14 | faya
# Processing Record 14 of Set 14 | lexington park
# Processing Record 15 of Set 14 | udimskiy
# Processing Record 16 of Set 14 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 17 of Set 14 | shirgaon
# Processing Record 18 of Set 14 | verkhnevilyuysk
# Processing Record 19 of Set 14 | port victoria
# Processing Record 20 of Set 14 | yenagoa
# Processing Record 21 of Set 14 | ulladulla
# Processing Record 22 of Set 14 | gazojak
# Processing Record 23 of Set 14 | hadgaon
# Processing Record 24 of Set 14 | mayumba
# Processing Record 25 of Set 14 | strezhevoy
# Processing Record 26 of Set 14 | benghazi
# Processing Record 27 of Set 14 | beyneu
# Processing Record 28 of Set 14 | ostrow mazowiecka
# Processing Record 29 of Set 14 | santa vitoria do palmar
# Processing Record 30 of Set 14 | vestmanna
# Processing Record 31 of Set 14 | grand gaube
# Processing Record 32 of Set 14 | pachperwa
# Processing Record 33 of Set 14 | meadow lake
# Processing Record 34 of Set 14 | uttarkashi
# Processing Record 35 of Set 14 | paita
# Processing Record 36 of Set 14 | birao
# Processing Record 37 of Set 14 | taitung
# Processing Record 38 of Set 14 | bani walid
# Processing Record 39 of Set 14 | thunder bay
# Processing Record 40 of Set 14 | jiazi
# Processing Record 41 of Set 14 | lima
# Processing Record 42 of Set 14 | coihueco
# Processing Record 43 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 44 of Set 14 | monrovia
# Processing Record 45 of Set 14 | katobu
# Processing Record 46 of Set 14 | kulykiv
# Processing Record 47 of Set 14 | bur gabo
# City not found. Skipping...
# Processing Record 48 of Set 14 | kuching
# Processing Record 49 of Set 14 | maple creek
# Processing Record 50 of Set 14 | tyukhtet
# Processing Record 1 of Set 15 | media luna
# Processing Record 2 of Set 15 | ormara
# Processing Record 3 of Set 15 | chicama
# Processing Record 4 of Set 15 | rehoboth
# Processing Record 5 of Set 15 | madaoua
# Processing Record 6 of Set 15 | rawah
# Processing Record 7 of Set 15 | merauke
# Processing Record 8 of Set 15 | lagoa
# Processing Record 9 of Set 15 | tokur
# Processing Record 10 of Set 15 | prado
# Processing Record 11 of Set 15 | karakendzha
# City not found. Skipping...
# Processing Record 12 of Set 15 | arlit
# Processing Record 13 of Set 15 | lexington
# Processing Record 14 of Set 15 | teguldet
# Processing Record 15 of Set 15 | mawlaik
# Processing Record 16 of Set 15 | krasnoyarsk-45
# City not found. Skipping...
# Processing Record 17 of Set 15 | tingo maria
# Processing Record 18 of Set 15 | dangriga
# Processing Record 19 of Set 15 | brownsville
# Processing Record 20 of Set 15 | maiduguri
# Processing Record 21 of Set 15 | tiruvottiyur
# City not found. Skipping...
# Processing Record 22 of Set 15 | burnie
# Processing Record 23 of Set 15 | thinadhoo
# Processing Record 24 of Set 15 | waterford
# Processing Record 25 of Set 15 | shimoda
# Processing Record 26 of Set 15 | granville
# Processing Record 27 of Set 15 | tiarei
# Processing Record 28 of Set 15 | petauke
# Processing Record 29 of Set 15 | sebezh
# Processing Record 30 of Set 15 | nova zagora
# Processing Record 31 of Set 15 | babanusah
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 666

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_order]

# Display sample data
city_data_df.head(10)

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
